# %% [markdown]
# <a href="https://colab.research.google.com/github/rupam1305/imdb/blob/main/IMDB_Case_Study_Question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
movies = pd.read_csv("IMDB_Movies.csv")# Write your code for importing the csv file here
movies
# Out:
#       color      director_name  ...  aspect_ratio  movie_facebook_likes
# 0     Color      James Cameron  ...          1.78                 33000
# 1     Color     Gore Verbinski  ...          2.35                     0
# 2     Color         Sam Mendes  ...          2.35                 85000
# 3     Color  Christopher Nolan  ...          2.35                164000
# 4       NaN        Doug Walker  ...           NaN                     0
# ...     ...                ...  ...           ...                   ...
# 5038  Color        Scott Smith  ...           NaN                    84
# 5039  Color                NaN  ...         16.00                 32000
# 5040  Color   Benjamin Roberds  ...           NaN                    16
# 5041  Color        Daniel Hsia  ...          2.35                   660
# 5042  Color           Jon Gunn  ...          1.85                   456
#
# [5043 rows x 28 columns]

# %% [markdown]
# -  ### Subtask 1.2: Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
# Write your code for inspection here
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
#  13  cast_total_facebook_likes  5043 non-null   int64
#  14  actor_3_name               5020 non-null   object
#  15  facenumber_in_poster       5030 non-null   float64
#  16  plot_keywords              4890 non-null   object
#  17  movie_imdb_link            5043 non-null   object
#  18  num_user_for_reviews       5023 non-null   object
#  19  language                   5031 non-null   object
#  20  country                    5038 non-null   object
#  21  content_rating             4740 non-null   object
#  22  budget                     4551 non-null   float64
#  23  title_year                 4935 non-null   float64
#  24  actor_2_facebook_likes     5030 non-null   float64
#  25  imdb_score                 5043 non-null   float64
#  26  aspect_ratio               4714 non-null   float64
#  27  movie_facebook_likes       5043 non-null   int64
# dtypes: float64(12), int64(3), object(13)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
# Write your code for column-wise null count here
null_values=pd.DataFrame({'column_name':movies.columns,"missing values":movies.isna().sum(),"percent missing value":round((movies.isna().sum()*100/len(movies)),2)})
null_values.set_index("column_name")
# Out:
#                            missing values  percent missing value
# column_name
# color                                  19                   0.38
# director_name                         104                   2.06
# num_critic_for_reviews                 50                   0.99
# duration                               15                   0.30
# director_facebook_likes               104                   2.06
# actor_3_facebook_likes                 23                   0.46
# actor_2_name                           13                   0.26
# actor_1_facebook_likes                  7                   0.14
# gross                                 884                  17.53
# genres                                  0                   0.00
# actor_1_name                            7                   0.14
# movie_title                             0                   0.00
# num_voted_users                         0                   0.00
# cast_total_facebook_likes               0                   0.00
# actor_3_name                           23                   0.46
# facenumber_in_poster                   13                   0.26
# plot_keywords                         153                   3.03
# movie_imdb_link                         0                   0.00
# num_user_for_reviews                   20                   0.40
# language                               12                   0.24
# country                                 5                   0.10
# content_rating                        303                   6.01
# budget                                492                   9.76
# title_year                            108                   2.14
# actor_2_facebook_likes                 13                   0.26
# imdb_score                              0                   0.00
# aspect_ratio                          329                   6.52
# movie_facebook_likes                    0                   0.00

# %%
# Write your code for row-wise null count here
movies.isna().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4       13
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
# Write your code for column-wise null percentages here
null_values=pd.DataFrame({'column_name':movies.columns,"percent missing value":round((movies.isna().sum()*100/len(movies)),2)})
null_values.set_index("column_name")
# Out:
#                            percent missing value
# column_name
# color                                       0.38
# director_name                               2.06
# num_critic_for_reviews                      0.99
# duration                                    0.30
# director_facebook_likes                     2.06
# actor_3_facebook_likes                      0.46
# actor_2_name                                0.26
# actor_1_facebook_likes                      0.14
# gross                                      17.53
# genres                                      0.00
# actor_1_name                                0.14
# movie_title                                 0.00
# num_voted_users                             0.00
# cast_total_facebook_likes                   0.00
# actor_3_name                                0.46
# facenumber_in_poster                        0.26
# plot_keywords                               3.03
# movie_imdb_link                             0.00
# num_user_for_reviews                        0.40
# language                                    0.24
# country                                     0.10
# content_rating                              6.01
# budget                                      9.76
# title_year                                  2.14
# actor_2_facebook_likes                      0.26
# imdb_score                                  0.00
# aspect_ratio                                6.52
# movie_facebook_likes                        0.00

# %%
#there is one othor method to calculate null value for each row
for i in range(len(movies)):
    print("Count of null values in row ",i,":",movies.iloc[i].isnull().sum())
# Out:
# Streaming output truncated to the last 5000 lines.
# Count of null values in row  43 : 0
# Count of null values in row  44 : 0
# Count of null values in row  45 : 0
# Count of null values in row  46 : 0
# Count of null values in row  47 : 0
# Count of null values in row  48 : 0
# Count of null values in row  49 : 0
# Count of null values in row  50 : 0
# Count of null values in row  51 : 0
# Count of null values in row  52 : 0
# Count of null values in row  53 : 0
# Count of null values in row  54 : 0
# Count of null values in row  55 : 1
# Count of null values in row  56 : 0
# Count of null values in row  57 : 0
# Count of null values in row  58 : 0
# Count of null values in row  59 : 0
# Count of null values in row  60 : 0
# Count of null values in row  61 : 0
# Count of null values in row  62 : 0
# Count of null values in row  63 : 0
# Count of null values in row  64 : 0
# Count of null values in row  65 : 0
# Count of null values in row  66 : 0
# Count of null values in row  67 : 0
# Count of null values in row  68 : 0
# Count of null values in row  69 : 0
# Count of null values in row  70 : 0
# Count of null values in row  71 : 0
# Count of null values in row  72 : 0
# Count of null values in row  73 : 0
# Count of null values in row  74 : 0
# Count of null values in row  75 : 0
# Count of null values in row  76 : 0
# Count of null values in row  77 : 0
# Count of null values in row  78 : 0
# Count of null values in row  79 : 0
# Count of null values in row  80 : 0
# Count of null values in row  81 : 0
# Count of null values in row  82 : 0
# Count of null values in row  83 : 0
# Count of null values in row  84 : 3
# Count of null values in row  85 : 0
# Count of null values in row  86 : 0
# Count of null values in row  87 : 0
# Count of null values in row  88 : 0
# Count of null values in row  89 : 0
# Count of null values in row  90 : 0
# Count of null values in row  91 : 0
# Count of null values in row  92 : 0
# Count of null values in row  93 : 0
# Count of null values in row  94 : 0
# Count of null values in row  95 : 0
# Count of null values in row  96 : 0
# Count of null values in row  97 : 0
# Count of null values in row  98 : 3
# Count of null values in row  99 : 1
# Count of null values in row  100 : 0
# Count of null values in row  101 : 0
# Count of null values in row  102 : 0
# Count of null values in row  103 : 0
# Count of null values in row  104 : 0
# Count of null values in row  105 : 0
# Count of null values in row  106 : 0
# Count of null values in row  107 : 0
# Count of null values in row  108 : 0
# Count of null values in row  109 : 0
# Count of null values in row  110 : 0
# Count of null values in row  111 : 0
# Count of null values in row  112 : 0
# Count of null values in row  113 : 0
# Count of null values in row  114 : 0
# Count of null values in row  115 : 0
# Count of null values in row  116 : 0
# Count of null values in row  117 : 0
# Count of null values in row  118 : 0
# Count of null values in row  119 : 0
# Count of null values in row  120 : 0
# Count of null values in row  121 : 0
# Count of null values in row  122 : 0
# Count of null values in row  123 : 0
# Count of null values in row  124 : 0
# Count of null values in row  125 : 0
# Count of null values in row  126 : 0
# Count of null values in row  127 : 0
# Count of null values in row  128 : 0
# Count of null values in row  129 : 0
# Count of null values in row  130 : 0
# Count of null values in row  131 : 0
# Count of null values in row  132 : 0
# Count of null values in row  133 : 0
# Count of null values in row  134 : 0
# Count of null values in row  135 : 0
# Count of null values in row  136 : 0
# Count of null values in row  137 : 0
# Count of null values in row  138 : 0
# Count of null values in row  139 : 0
# Count of null values in row  140 : 0
# Count of null values in row  141 : 0
# Count of null values in row  142 : 0
# Count of null values in row  143 : 0
# Count of null values in row  144 : 0
# Count of null values in row  145 : 0
# Count of null values in row  146 : 0
# Count of null values in row  147 : 0
# Count of null values in row  148 : 0
# Count of null values in row  149 : 0
# Count of null values in row  150 : 0
# Count of null values in row  151 : 0
# Count of null values in row  152 : 0
# Count of null values in row  153 : 0
# Count of null values in row  154 : 0
# Count of null values in row  155 : 0
# Count of null values in row  156 : 0
# Count of null values in row  157 : 0
# Count of null values in row  158 : 0
# Count of null values in row  159 : 0
# Count of null values in row  160 : 0
# Count of null values in row  161 : 0
# Count of null values in row  162 : 0
# Count of null values in row  163 : 0
# Count of null values in row  164 : 0
# Count of null values in row  165 : 0
# Count of null values in row  166 : 0
# Count of null values in row  167 : 0
# Count of null values in row  168 : 0
# Count of null values in row  169 : 0
# Count of null values in row  170 : 0
# Count of null values in row  171 : 0
# Count of null values in row  172 : 0
# Count of null values in row  173 : 0
# Count of null values in row  174 : 0
# Count of null values in row  175 : 0
# Count of null values in row  176 : 0
# Count of null values in row  177 : 4
# Count of null values in row  178 : 0
# Count of null values in row  179 : 0
# Count of null values in row  180 : 0
# Count of null values in row  181 : 0
# Count of null values in row  182 : 0
# Count of null values in row  183 : 0
# Count of null values in row  184 : 0
# Count of null values in row  185 : 0
# Count of null values in row  186 : 0
# Count of null values in row  187 : 0
# Count of null values in row  188 : 0
# Count of null values in row  189 : 0
# Count of null values in row  190 : 0
# Count of null values in row  191 : 0
# Count of null values in row  192 : 0
# Count of null values in row  193 : 0
# Count of null values in row  194 : 0
# Count of null values in row  195 : 0
# Count of null values in row  196 : 0
# Count of null values in row  197 : 0
# Count of null values in row  198 : 0
# Count of null values in row  199 : 6
# Count of null values in row  200 : 0
# Count of null values in row  201 : 0
# Count of null values in row  202 : 0
# Count of null values in row  203 : 0
# Count of null values in row  204 : 3
# Count of null values in row  205 : 0
# Count of null values in row  206 : 6
# Count of null values in row  207 : 0
# Count of null values in row  208 : 0
# Count of null values in row  209 : 0
# Count of null values in row  210 : 0
# Count of null values in row  211 : 0
# Count of null values in row  212 : 0
# Count of null values in row  213 : 0
# Count of null values in row  214 : 0
# Count of null values in row  215 : 0
# Count of null values in row  216 : 0
# Count of null values in row  217 : 0
# Count of null values in row  218 : 0
# Count of null values in row  219 : 0
# Count of null values in row  220 : 0
# Count of null values in row  221 : 0
# Count of null values in row  222 : 0
# Count of null values in row  223 : 0
# Count of null values in row  224 : 0
# Count of null values in row  225 : 0
# Count of null values in row  226 : 0
# Count of null values in row  227 : 0
# Count of null values in row  228 : 0
# Count of null values in row  229 : 0
# Count of null values in row  230 : 0
# Count of null values in row  231 : 0
# Count of null values in row  232 : 0
# Count of null values in row  233 : 0
# Count of null values in row  234 : 0
# Count of null values in row  235 : 0
# Count of null values in row  236 : 0
# Count of null values in row  237 : 0
# Count of null values in row  238 : 0
# Count of null values in row  239 : 0
# Count of null values in row  240 : 0
# Count of null values in row  241 : 0
# Count of null values in row  242 : 2
# Count of null values in row  243 : 0
# Count of null values in row  244 : 0
# Count of null values in row  245 : 0
# Count of null values in row  246 : 0
# Count of null values in row  247 : 0
# Count of null values in row  248 : 1
# Count of null values in row  249 : 0
# Count of null values in row  250 : 0
# Count of null values in row  251 : 0
# Count of null values in row  252 : 0
# Count of null values in row  253 : 0
# Count of null values in row  254 : 0
# Count of null values in row  255 : 0
# Count of null values in row  256 : 0
# Count of null values in row  257 : 0
# Count of null values in row  258 : 0
# Count of null values in row  259 : 0
# Count of null values in row  260 : 5
# Count of null values in row  261 : 0
# Count of null values in row  262 : 0
# Count of null values in row  263 : 0
# Count of null values in row  264 : 0
# Count of null values in row  265 : 0
# Count of null values in row  266 : 0
# Count of null values in row  267 : 0
# Count of null values in row  268 : 0
# Count of null values in row  269 : 0
# Count of null values in row  270 : 0
# Count of null values in row  271 : 0
# Count of null values in row  272 : 0
# Count of null values in row  273 : 0
# Count of null values in row  274 : 0
# Count of null values in row  275 : 0
# Count of null values in row  276 : 0
# Count of null values in row  277 : 0
# Count of null values in row  278 : 0
# Count of null values in row  279 : 15
# Count of null values in row  280 : 0
# Count of null values in row  281 : 0
# Count of null values in row  282 : 0
# Count of null values in row  283 : 0
# Count of null values in row  284 : 0
# Count of null values in row  285 : 0
# Count of null values in row  286 : 0
# Count of null values in row  287 : 0
# Count of null values in row  288 : 0
# Count of null values in row  289 : 0
# Count of null values in row  290 : 0
# Count of null values in row  291 : 0
# Count of null values in row  292 : 0
# Count of null values in row  293 : 0
# Count of null values in row  294 : 0
# Count of null values in row  295 : 0
# Count of null values in row  296 : 0
# Count of null values in row  297 : 0
# Count of null values in row  298 : 0
# Count of null values in row  299 : 0
# Count of null values in row  300 : 0
# Count of null values in row  301 : 0
# Count of null values in row  302 : 0
# Count of null values in row  303 : 0
# Count of null values in row  304 : 0
# Count of null values in row  305 : 0
# Count of null values in row  306 : 0
# Count of null values in row  307 : 0
# Count of null values in row  308 : 0
# Count of null values in row  309 : 0
# Count of null values in row  310 : 0
# Count of null values in row  311 : 0
# Count of null values in row  312 : 0
# Count of null values in row  313 : 0
# Count of null values in row  314 : 0
# Count of null values in row  315 : 0
# Count of null values in row  316 : 0
# Count of null values in row  317 : 0
# Count of null values in row  318 : 0
# Count of null values in row  319 : 0
# Count of null values in row  320 : 0
# Count of null values in row  321 : 0
# Count of null values in row  322 : 0
# Count of null values in row  323 : 0
# Count of null values in row  324 : 0
# Count of null values in row  325 : 0
# Count of null values in row  326 : 0
# Count of null values in row  327 : 0
# Count of null values in row  328 : 0
# Count of null values in row  329 : 0
# Count of null values in row  330 : 0
# Count of null values in row  331 : 0
# Count of null values in row  332 : 0
# Count of null values in row  333 : 0
# Count of null values in row  334 : 0
# Count of null values in row  335 : 0
# Count of null values in row  336 : 0
# Count of null values in row  337 : 0
# Count of null values in row  338 : 0
# Count of null values in row  339 : 0
# Count of null values in row  340 : 0
# Count of null values in row  341 : 0
# Count of null values in row  342 : 0
# Count of null values in row  343 : 0
# Count of null values in row  344 : 0
# Count of null values in row  345 : 0
# Count of null values in row  346 : 0
# Count of null values in row  347 : 0
# Count of null values in row  348 : 0
# Count of null values in row  349 : 0
# Count of null values in row  350 : 0
# Count of null values in row  351 : 0
# Count of null values in row  352 : 0
# Count of null values in row  353 : 0
# Count of null values in row  354 : 0
# Count of null values in row  355 : 0
# Count of null values in row  356 : 0
# Count of null values in row  357 : 0
# Count of null values in row  358 : 0
# Count of null values in row  359 : 0
# Count of null values in row  360 : 0
# Count of null values in row  361 : 0
# Count of null values in row  362 : 0
# Count of null values in row  363 : 0
# Count of null values in row  364 : 0
# Count of null values in row  365 : 0
# Count of null values in row  366 : 0
# Count of null values in row  367 : 3
# Count of null values in row  368 : 0
# Count of null values in row  369 : 0
# Count of null values in row  370 : 0
# Count of null values in row  371 : 0
# Count of null values in row  372 : 0
# Count of null values in row  373 : 0
# Count of null values in row  374 : 0
# Count of null values in row  375 : 0
# Count of null values in row  376 : 0
# Count of null values in row  377 : 0
# Count of null values in row  378 : 0
# Count of null values in row  379 : 0
# Count of null values in row  380 : 0
# Count of null values in row  381 : 0
# Count of null values in row  382 : 0
# Count of null values in row  383 : 0
# Count of null values in row  384 : 0
# Count of null values in row  385 : 0
# Count of null values in row  386 : 0
# Count of null values in row  387 : 0
# Count of null values in row  388 : 0
# Count of null values in row  389 : 0
# Count of null values in row  390 : 0
# Count of null values in row  391 : 0
# Count of null values in row  392 : 0
# Count of null values in row  393 : 0
# Count of null values in row  394 : 0
# Count of null values in row  395 : 0
# Count of null values in row  396 : 0
# Count of null values in row  397 : 0
# Count of null values in row  398 : 0
# Count of null values in row  399 : 0
# Count of null values in row  400 : 0
# Count of null values in row  401 : 0
# Count of null values in row  402 : 0
# Count of null values in row  403 : 0
# Count of null values in row  404 : 5
# Count of null values in row  405 : 0
# Count of null values in row  406 : 0
# Count of null values in row  407 : 0
# Count of null values in row  408 : 0
# Count of null values in row  409 : 0
# Count of null values in row  410 : 0
# Count of null values in row  411 : 0
# Count of null values in row  412 : 0
# Count of null values in row  413 : 0
# Count of null values in row  414 : 0
# Count of null values in row  415 : 0
# Count of null values in row  416 : 0
# Count of null values in row  417 : 0
# Count of null values in row  418 : 0
# Count of null values in row  419 : 0
# Count of null values in row  420 : 0
# Count of null values in row  421 : 0
# Count of null values in row  422 : 2
# Count of null values in row  423 : 0
# Count of null values in row  424 : 0
# Count of null values in row  425 : 0
# Count of null values in row  426 : 0
# Count of null values in row  427 : 0
# Count of null values in row  428 : 0
# Count of null values in row  429 : 0
# Count of null values in row  430 : 1
# Count of null values in row  431 : 0
# Count of null values in row  432 : 0
# Count of null values in row  433 : 0
# Count of null values in row  434 : 0
# Count of null values in row  435 : 0
# Count of null values in row  436 : 0
# Count of null values in row  437 : 0
# Count of null values in row  438 : 0
# Count of null values in row  439 : 0
# Count of null values in row  440 : 0
# Count of null values in row  441 : 0
# Count of null values in row  442 : 0
# Count of null values in row  443 : 0
# Count of null values in row  444 : 1
# Count of null values in row  445 : 0
# Count of null values in row  446 : 0
# Count of null values in row  447 : 0
# Count of null values in row  448 : 0
# Count of null values in row  449 : 0
# Count of null values in row  450 : 0
# Count of null values in row  451 : 0
# Count of null values in row  452 : 0
# Count of null values in row  453 : 0
# Count of null values in row  454 : 0
# Count of null values in row  455 : 0
# Count of null values in row  456 : 0
# Count of null values in row  457 : 0
# Count of null values in row  458 : 0
# Count of null values in row  459 : 6
# Count of null values in row  460 : 0
# Count of null values in row  461 : 0
# Count of null values in row  462 : 0
# Count of null values in row  463 : 0
# Count of null values in row  464 : 0
# Count of null values in row  465 : 0
# Count of null values in row  466 : 0
# Count of null values in row  467 : 0
# Count of null values in row  468 : 0
# Count of null values in row  469 : 0
# Count of null values in row  470 : 0
# Count of null values in row  471 : 0
# Count of null values in row  472 : 0
# Count of null values in row  473 : 0
# Count of null values in row  474 : 0
# Count of null values in row  475 : 0
# Count of null values in row  476 : 0
# Count of null values in row  477 : 1
# Count of null values in row  478 : 0
# Count of null values in row  479 : 5
# Count of null values in row  480 : 0
# Count of null values in row  481 : 0
# Count of null values in row  482 : 0
# Count of null values in row  483 : 0
# Count of null values in row  484 : 0
# Count of null values in row  485 : 0
# Count of null values in row  486 : 0
# Count of null values in row  487 : 0
# Count of null values in row  488 : 0
# Count of null values in row  489 : 3
# Count of null values in row  490 : 1
# Count of null values in row  491 : 0
# Count of null values in row  492 : 0
# Count of null values in row  493 : 0
# Count of null values in row  494 : 0
# Count of null values in row  495 : 0
# Count of null values in row  496 : 0
# Count of null values in row  497 : 0
# Count of null values in row  498 : 0
# Count of null values in row  499 : 0
# Count of null values in row  500 : 0
# Count of null values in row  501 : 0
# Count of null values in row  502 : 0
# Count of null values in row  503 : 0
# Count of null values in row  504 : 0
# Count of null values in row  505 : 0
# Count of null values in row  506 : 0
# Count of null values in row  507 : 3
# Count of null values in row  508 : 0
# Count of null values in row  509 : 0
# Count of null values in row  510 : 0
# Count of null values in row  511 : 0
# Count of null values in row  512 : 0
# Count of null values in row  513 : 0
# Count of null values in row  514 : 0
# Count of null values in row  515 : 0
# Count of null values in row  516 : 0
# Count of null values in row  517 : 0
# Count of null values in row  518 : 0
# Count of null values in row  519 : 0
# Count of null values in row  520 : 0
# Count of null values in row  521 : 0
# Count of null values in row  522 : 0
# Count of null values in row  523 : 0
# Count of null values in row  524 : 0
# Count of null values in row  525 : 0
# Count of null values in row  526 : 0
# Count of null values in row  527 : 0
# Count of null values in row  528 : 0
# Count of null values in row  529 : 0
# Count of null values in row  530 : 0
# Count of null values in row  531 : 0
# Count of null values in row  532 : 0
# Count of null values in row  533 : 0
# Count of null values in row  534 : 0
# Count of null values in row  535 : 0
# Count of null values in row  536 : 0
# Count of null values in row  537 : 5
# Count of null values in row  538 : 0
# Count of null values in row  539 : 0
# Count of null values in row  540 : 0
# Count of null values in row  541 : 0
# Count of null values in row  542 : 0
# Count of null values in row  543 : 7
# Count of null values in row  544 : 0
# Count of null values in row  545 : 0
# Count of null values in row  546 : 0
# Count of null values in row  547 : 0
# Count of null values in row  548 : 0
# Count of null values in row  549 : 0
# Count of null values in row  550 : 0
# Count of null values in row  551 : 0
# Count of null values in row  552 : 0
# Count of null values in row  553 : 0
# Count of null values in row  554 : 0
# Count of null values in row  555 : 0
# Count of null values in row  556 : 0
# Count of null values in row  557 : 0
# Count of null values in row  558 : 0
# Count of null values in row  559 : 1
# Count of null values in row  560 : 0
# Count of null values in row  561 : 0
# Count of null values in row  562 : 0
# Count of null values in row  563 : 0
# Count of null values in row  564 : 0
# Count of null values in row  565 : 0
# Count of null values in row  566 : 0
# Count of null values in row  567 : 0
# Count of null values in row  568 : 0
# Count of null values in row  569 : 0
# Count of null values in row  570 : 0
# Count of null values in row  571 : 0
# Count of null values in row  572 : 0
# Count of null values in row  573 : 0
# Count of null values in row  574 : 0
# Count of null values in row  575 : 0
# Count of null values in row  576 : 0
# Count of null values in row  577 : 0
# Count of null values in row  578 : 0
# Count of null values in row  579 : 0
# Count of null values in row  580 : 0
# Count of null values in row  581 : 0
# Count of null values in row  582 : 0
# Count of null values in row  583 : 0
# Count of null values in row  584 : 0
# Count of null values in row  585 : 0
# Count of null values in row  586 : 0
# Count of null values in row  587 : 0
# Count of null values in row  588 : 0
# Count of null values in row  589 : 0
# Count of null values in row  590 : 0
# Count of null values in row  591 : 0
# Count of null values in row  592 : 0
# Count of null values in row  593 : 5
# Count of null values in row  594 : 0
# Count of null values in row  595 : 0
# Count of null values in row  596 : 0
# Count of null values in row  597 : 0
# Count of null values in row  598 : 0
# Count of null values in row  599 : 0
# Count of null values in row  600 : 0
# Count of null values in row  601 : 0
# Count of null values in row  602 : 0
# Count of null values in row  603 : 0
# Count of null values in row  604 : 0
# Count of null values in row  605 : 0
# Count of null values in row  606 : 0
# Count of null values in row  607 : 0
# Count of null values in row  608 : 0
# Count of null values in row  609 : 0
# Count of null values in row  610 : 0
# Count of null values in row  611 : 0
# Count of null values in row  612 : 0
# Count of null values in row  613 : 0
# Count of null values in row  614 : 0
# Count of null values in row  615 : 0
# Count of null values in row  616 : 0
# Count of null values in row  617 : 0
# Count of null values in row  618 : 0
# Count of null values in row  619 : 0
# Count of null values in row  620 : 0
# Count of null values in row  621 : 0
# Count of null values in row  622 : 0
# Count of null values in row  623 : 0
# Count of null values in row  624 : 1
# Count of null values in row  625 : 0
# Count of null values in row  626 : 0
# Count of null values in row  627 : 0
# Count of null values in row  628 : 0
# Count of null values in row  629 : 0
# Count of null values in row  630 : 0
# Count of null values in row  631 : 0
# Count of null values in row  632 : 0
# Count of null values in row  633 : 0
# Count of null values in row  634 : 0
# Count of null values in row  635 : 0
# Count of null values in row  636 : 0
# Count of null values in row  637 : 0
# Count of null values in row  638 : 0
# Count of null values in row  639 : 0
# Count of null values in row  640 : 1
# Count of null values in row  641 : 0
# Count of null values in row  642 : 1
# Count of null values in row  643 : 0
# Count of null values in row  644 : 0
# Count of null values in row  645 : 5
# Count of null values in row  646 : 0
# Count of null values in row  647 : 0
# Count of null values in row  648 : 0
# Count of null values in row  649 : 0
# Count of null values in row  650 : 0
# Count of null values in row  651 : 0
# Count of null values in row  652 : 0
# Count of null values in row  653 : 0
# Count of null values in row  654 : 0
# Count of null values in row  655 : 0
# Count of null values in row  656 : 0
# Count of null values in row  657 : 0
# Count of null values in row  658 : 0
# Count of null values in row  659 : 0
# Count of null values in row  660 : 0
# Count of null values in row  661 : 0
# Count of null values in row  662 : 0
# Count of null values in row  663 : 0
# Count of null values in row  664 : 0
# Count of null values in row  665 : 0
# Count of null values in row  666 : 0
# Count of null values in row  667 : 0
# Count of null values in row  668 : 0
# Count of null values in row  669 : 0
# Count of null values in row  670 : 0
# Count of null values in row  671 : 0
# Count of null values in row  672 : 0
# Count of null values in row  673 : 0
# Count of null values in row  674 : 0
# Count of null values in row  675 : 0
# Count of null values in row  676 : 1
# Count of null values in row  677 : 0
# Count of null values in row  678 : 0
# Count of null values in row  679 : 0
# Count of null values in row  680 : 0
# Count of null values in row  681 : 0
# Count of null values in row  682 : 0
# Count of null values in row  683 : 0
# Count of null values in row  684 : 0
# Count of null values in row  685 : 7
# Count of null values in row  686 : 0
# Count of null values in row  687 : 0
# Count of null values in row  688 : 0
# Count of null values in row  689 : 0
# Count of null values in row  690 : 0
# Count of null values in row  691 : 0
# Count of null values in row  692 : 0
# Count of null values in row  693 : 0
# Count of null values in row  694 : 0
# Count of null values in row  695 : 0
# Count of null values in row  696 : 0
# Count of null values in row  697 : 0
# Count of null values in row  698 : 0
# Count of null values in row  699 : 0
# Count of null values in row  700 : 0
# Count of null values in row  701 : 0
# Count of null values in row  702 : 0
# Count of null values in row  703 : 0
# Count of null values in row  704 : 0
# Count of null values in row  705 : 0
# Count of null values in row  706 : 0
# Count of null values in row  707 : 0
# Count of null values in row  708 : 0
# Count of null values in row  709 : 0
# Count of null values in row  710 : 0
# Count of null values in row  711 : 0
# Count of null values in row  712 : 0
# Count of null values in row  713 : 1
# Count of null values in row  714 : 0
# Count of null values in row  715 : 0
# Count of null values in row  716 : 0
# Count of null values in row  717 : 0
# Count of null values in row  718 : 0
# Count of null values in row  719 : 0
# Count of null values in row  720 : 0
# Count of null values in row  721 : 0
# Count of null values in row  722 : 0
# Count of null values in row  723 : 0
# Count of null values in row  724 : 0
# Count of null values in row  725 : 0
# Count of null values in row  726 : 0
# Count of null values in row  727 : 0
# Count of null values in row  728 : 0
# Count of null values in row  729 : 0
# Count of null values in row  730 : 0
# Count of null values in row  731 : 0
# Count of null values in row  732 : 0
# Count of null values in row  733 : 0
# Count of null values in row  734 : 0
# Count of null values in row  735 : 0
# Count of null values in row  736 : 0
# Count of null values in row  737 : 0
# Count of null values in row  738 : 0
# Count of null values in row  739 : 0
# Count of null values in row  740 : 0
# Count of null values in row  741 : 0
# Count of null values in row  742 : 0
# Count of null values in row  743 : 0
# Count of null values in row  744 : 0
# Count of null values in row  745 : 0
# Count of null values in row  746 : 0
# Count of null values in row  747 : 0
# Count of null values in row  748 : 0
# Count of null values in row  749 : 0
# Count of null values in row  750 : 0
# Count of null values in row  751 : 0
# Count of null values in row  752 : 0
# Count of null values in row  753 : 0
# Count of null values in row  754 : 0
# Count of null values in row  755 : 0
# Count of null values in row  756 : 0
# Count of null values in row  757 : 5
# Count of null values in row  758 : 0
# Count of null values in row  759 : 0
# Count of null values in row  760 : 0
# Count of null values in row  761 : 0
# Count of null values in row  762 : 0
# Count of null values in row  763 : 0
# Count of null values in row  764 : 0
# Count of null values in row  765 : 0
# Count of null values in row  766 : 0
# Count of null values in row  767 : 0
# Count of null values in row  768 : 0
# Count of null values in row  769 : 0
# Count of null values in row  770 : 0
# Count of null values in row  771 : 0
# Count of null values in row  772 : 0
# Count of null values in row  773 : 1
# Count of null values in row  774 : 0
# Count of null values in row  775 : 0
# Count of null values in row  776 : 0
# Count of null values in row  777 : 0
# Count of null values in row  778 : 0
# Count of null values in row  779 : 0
# Count of null values in row  780 : 1
# Count of null values in row  781 : 0
# Count of null values in row  782 : 0
# Count of null values in row  783 : 0
# Count of null values in row  784 : 0
# Count of null values in row  785 : 0
# Count of null values in row  786 : 0
# Count of null values in row  787 : 0
# Count of null values in row  788 : 0
# Count of null values in row  789 : 1
# Count of null values in row  790 : 0
# Count of null values in row  791 : 0
# Count of null values in row  792 : 0
# Count of null values in row  793 : 0
# Count of null values in row  794 : 0
# Count of null values in row  795 : 0
# Count of null values in row  796 : 0
# Count of null values in row  797 : 0
# Count of null values in row  798 : 0
# Count of null values in row  799 : 0
# Count of null values in row  800 : 0
# Count of null values in row  801 : 0
# Count of null values in row  802 : 0
# Count of null values in row  803 : 0
# Count of null values in row  804 : 0
# Count of null values in row  805 : 0
# Count of null values in row  806 : 0
# Count of null values in row  807 : 0
# Count of null values in row  808 : 0
# Count of null values in row  809 : 0
# Count of null values in row  810 : 2
# Count of null values in row  811 : 0
# Count of null values in row  812 : 0
# Count of null values in row  813 : 0
# Count of null values in row  814 : 0
# Count of null values in row  815 : 0
# Count of null values in row  816 : 4
# Count of null values in row  817 : 0
# Count of null values in row  818 : 0
# Count of null values in row  819 : 0
# Count of null values in row  820 : 0
# Count of null values in row  821 : 2
# Count of null values in row  822 : 0
# Count of null values in row  823 : 0
# Count of null values in row  824 : 0
# Count of null values in row  825 : 0
# Count of null values in row  826 : 5
# Count of null values in row  827 : 0
# Count of null values in row  828 : 0
# Count of null values in row  829 : 0
# Count of null values in row  830 : 0
# Count of null values in row  831 : 0
# Count of null values in row  832 : 0
# Count of null values in row  833 : 6
# Count of null values in row  834 : 0
# Count of null values in row  835 : 0
# Count of null values in row  836 : 0
# Count of null values in row  837 : 0
# Count of null values in row  838 : 0
# Count of null values in row  839 : 0
# Count of null values in row  840 : 0
# Count of null values in row  841 : 0
# Count of null values in row  842 : 0
# Count of null values in row  843 : 0
# Count of null values in row  844 : 0
# Count of null values in row  845 : 0
# Count of null values in row  846 : 0
# Count of null values in row  847 : 0
# Count of null values in row  848 : 0
# Count of null values in row  849 : 0
# Count of null values in row  850 : 0
# Count of null values in row  851 : 0
# Count of null values in row  852 : 0
# Count of null values in row  853 : 0
# Count of null values in row  854 : 0
# Count of null values in row  855 : 0
# Count of null values in row  856 : 0
# Count of null values in row  857 : 4
# Count of null values in row  858 : 0
# Count of null values in row  859 : 0
# Count of null values in row  860 : 0
# Count of null values in row  861 : 0
# Count of null values in row  862 : 0
# Count of null values in row  863 : 0
# Count of null values in row  864 : 0
# Count of null values in row  865 : 0
# Count of null values in row  866 : 0
# Count of null values in row  867 : 0
# Count of null values in row  868 : 0
# Count of null values in row  869 : 0
# Count of null values in row  870 : 0
# Count of null values in row  871 : 0
# Count of null values in row  872 : 0
# Count of null values in row  873 : 0
# Count of null values in row  874 : 0
# Count of null values in row  875 : 0
# Count of null values in row  876 : 0
# Count of null values in row  877 : 0
# Count of null values in row  878 : 0
# Count of null values in row  879 : 0
# Count of null values in row  880 : 0
# Count of null values in row  881 : 0
# Count of null values in row  882 : 0
# Count of null values in row  883 : 0
# Count of null values in row  884 : 0
# Count of null values in row  885 : 0
# Count of null values in row  886 : 0
# Count of null values in row  887 : 0
# Count of null values in row  888 : 0
# Count of null values in row  889 : 0
# Count of null values in row  890 : 1
# Count of null values in row  891 : 1
# Count of null values in row  892 : 0
# Count of null values in row  893 : 0
# Count of null values in row  894 : 0
# Count of null values in row  895 : 0
# Count of null values in row  896 : 0
# Count of null values in row  897 : 0
# Count of null values in row  898 : 0
# Count of null values in row  899 : 0
# Count of null values in row  900 : 0
# Count of null values in row  901 : 0
# Count of null values in row  902 : 0
# Count of null values in row  903 : 0
# Count of null values in row  904 : 0
# Count of null values in row  905 : 0
# Count of null values in row  906 : 0
# Count of null values in row  907 : 0
# Count of null values in row  908 : 0
# Count of null values in row  909 : 0
# Count of null values in row  910 : 0
# Count of null values in row  911 : 0
# Count of null values in row  912 : 0
# Count of null values in row  913 : 0
# Count of null values in row  914 : 0
# Count of null values in row  915 : 0
# Count of null values in row  916 : 0
# Count of null values in row  917 : 0
# Count of null values in row  918 : 0
# Count of null values in row  919 : 0
# Count of null values in row  920 : 0
# Count of null values in row  921 : 0
# Count of null values in row  922 : 0
# Count of null values in row  923 : 0
# Count of null values in row  924 : 0
# Count of null values in row  925 : 1
# Count of null values in row  926 : 0
# Count of null values in row  927 : 0
# Count of null values in row  928 : 0
# Count of null values in row  929 : 0
# Count of null values in row  930 : 0
# Count of null values in row  931 : 0
# Count of null values in row  932 : 0
# Count of null values in row  933 : 0
# Count of null values in row  934 : 0
# Count of null values in row  935 : 0
# Count of null values in row  936 : 0
# Count of null values in row  937 : 0
# Count of null values in row  938 : 0
# Count of null values in row  939 : 0
# Count of null values in row  940 : 0
# Count of null values in row  941 : 0
# Count of null values in row  942 : 0
# Count of null values in row  943 : 0
# Count of null values in row  944 : 0
# Count of null values in row  945 : 0
# Count of null values in row  946 : 0
# Count of null values in row  947 : 0
# Count of null values in row  948 : 0
# Count of null values in row  949 : 1
# Count of null values in row  950 : 0
# Count of null values in row  951 : 0
# Count of null values in row  952 : 1
# Count of null values in row  953 : 0
# Count of null values in row  954 : 0
# Count of null values in row  955 : 0
# Count of null values in row  956 : 0
# Count of null values in row  957 : 0
# Count of null values in row  958 : 0
# Count of null values in row  959 : 0
# Count of null values in row  960 : 0
# Count of null values in row  961 : 0
# Count of null values in row  962 : 8
# Count of null values in row  963 : 0
# Count of null values in row  964 : 0
# Count of null values in row  965 : 0
# Count of null values in row  966 : 0
# Count of null values in row  967 : 0
# Count of null values in row  968 : 0
# Count of null values in row  969 : 0
# Count of null values in row  970 : 0
# Count of null values in row  971 : 0
# Count of null values in row  972 : 0
# Count of null values in row  973 : 0
# Count of null values in row  974 : 0
# Count of null values in row  975 : 0
# Count of null values in row  976 : 0
# Count of null values in row  977 : 0
# Count of null values in row  978 : 0
# Count of null values in row  979 : 0
# Count of null values in row  980 : 0
# Count of null values in row  981 : 0
# Count of null values in row  982 : 0
# Count of null values in row  983 : 0
# Count of null values in row  984 : 0
# Count of null values in row  985 : 0
# Count of null values in row  986 : 0
# Count of null values in row  987 : 0
# Count of null values in row  988 : 0
# Count of null values in row  989 : 0
# Count of null values in row  990 : 0
# Count of null values in row  991 : 0
# Count of null values in row  992 : 0
# Count of null values in row  993 : 0
# Count of null values in row  994 : 6
# Count of null values in row  995 : 0
# Count of null values in row  996 : 0
# Count of null values in row  997 : 0
# Count of null values in row  998 : 0
# Count of null values in row  999 : 0
# Count of null values in row  1000 : 0
# Count of null values in row  1001 : 0
# Count of null values in row  1002 : 0
# Count of null values in row  1003 : 0
# Count of null values in row  1004 : 0
# Count of null values in row  1005 : 0
# Count of null values in row  1006 : 0
# Count of null values in row  1007 : 7
# Count of null values in row  1008 : 0
# Count of null values in row  1009 : 0
# Count of null values in row  1010 : 0
# Count of null values in row  1011 : 0
# Count of null values in row  1012 : 0
# Count of null values in row  1013 : 0
# Count of null values in row  1014 : 0
# Count of null values in row  1015 : 0
# Count of null values in row  1016 : 0
# Count of null values in row  1017 : 0
# Count of null values in row  1018 : 0
# Count of null values in row  1019 : 0
# Count of null values in row  1020 : 0
# Count of null values in row  1021 : 0
# Count of null values in row  1022 : 0
# Count of null values in row  1023 : 5
# Count of null values in row  1024 : 0
# Count of null values in row  1025 : 0
# Count of null values in row  1026 : 0
# Count of null values in row  1027 : 0
# Count of null values in row  1028 : 0
# Count of null values in row  1029 : 0
# Count of null values in row  1030 : 0
# Count of null values in row  1031 : 0
# Count of null values in row  1032 : 0
# Count of null values in row  1033 : 0
# Count of null values in row  1034 : 0
# Count of null values in row  1035 : 5
# Count of null values in row  1036 : 0
# Count of null values in row  1037 : 1
# Count of null values in row  1038 : 0
# Count of null values in row  1039 : 0
# Count of null values in row  1040 : 1
# Count of null values in row  1041 : 0
# Count of null values in row  1042 : 0
# Count of null values in row  1043 : 0
# Count of null values in row  1044 : 2
# Count of null values in row  1045 : 0
# Count of null values in row  1046 : 0
# Count of null values in row  1047 : 0
# Count of null values in row  1048 : 0
# Count of null values in row  1049 : 0
# Count of null values in row  1050 : 0
# Count of null values in row  1051 : 0
# Count of null values in row  1052 : 0
# Count of null values in row  1053 : 0
# Count of null values in row  1054 : 0
# Count of null values in row  1055 : 0
# Count of null values in row  1056 : 2
# Count of null values in row  1057 : 0
# Count of null values in row  1058 : 0
# Count of null values in row  1059 : 0
# Count of null values in row  1060 : 1
# Count of null values in row  1061 : 1
# Count of null values in row  1062 : 0
# Count of null values in row  1063 : 0
# Count of null values in row  1064 : 0
# Count of null values in row  1065 : 0
# Count of null values in row  1066 : 0
# Count of null values in row  1067 : 0
# Count of null values in row  1068 : 0
# Count of null values in row  1069 : 0
# Count of null values in row  1070 : 0
# Count of null values in row  1071 : 1
# Count of null values in row  1072 : 1
# Count of null values in row  1073 : 0
# Count of null values in row  1074 : 0
# Count of null values in row  1075 : 0
# Count of null values in row  1076 : 0
# Count of null values in row  1077 : 0
# Count of null values in row  1078 : 0
# Count of null values in row  1079 : 0
# Count of null values in row  1080 : 0
# Count of null values in row  1081 : 0
# Count of null values in row  1082 : 0
# Count of null values in row  1083 : 0
# Count of null values in row  1084 : 0
# Count of null values in row  1085 : 0
# Count of null values in row  1086 : 0
# Count of null values in row  1087 : 0
# Count of null values in row  1088 : 0
# Count of null values in row  1089 : 0
# Count of null values in row  1090 : 0
# Count of null values in row  1091 : 0
# Count of null values in row  1092 : 0
# Count of null values in row  1093 : 0
# Count of null values in row  1094 : 0
# Count of null values in row  1095 : 0
# Count of null values in row  1096 : 0
# Count of null values in row  1097 : 0
# Count of null values in row  1098 : 0
# Count of null values in row  1099 : 1
# Count of null values in row  1100 : 0
# Count of null values in row  1101 : 0
# Count of null values in row  1102 : 0
# Count of null values in row  1103 : 0
# Count of null values in row  1104 : 0
# Count of null values in row  1105 : 0
# Count of null values in row  1106 : 0
# Count of null values in row  1107 : 0
# Count of null values in row  1108 : 0
# Count of null values in row  1109 : 0
# Count of null values in row  1110 : 0
# Count of null values in row  1111 : 0
# Count of null values in row  1112 : 0
# Count of null values in row  1113 : 0
# Count of null values in row  1114 : 0
# Count of null values in row  1115 : 0
# Count of null values in row  1116 : 0
# Count of null values in row  1117 : 0
# Count of null values in row  1118 : 0
# Count of null values in row  1119 : 0
# Count of null values in row  1120 : 0
# Count of null values in row  1121 : 0
# Count of null values in row  1122 : 0
# Count of null values in row  1123 : 0
# Count of null values in row  1124 : 0
# Count of null values in row  1125 : 0
# Count of null values in row  1126 : 0
# Count of null values in row  1127 : 0
# Count of null values in row  1128 : 0
# Count of null values in row  1129 : 0
# Count of null values in row  1130 : 0
# Count of null values in row  1131 : 0
# Count of null values in row  1132 : 0
# Count of null values in row  1133 : 5
# Count of null values in row  1134 : 0
# Count of null values in row  1135 : 0
# Count of null values in row  1136 : 2
# Count of null values in row  1137 : 0
# Count of null values in row  1138 : 0
# Count of null values in row  1139 : 0
# Count of null values in row  1140 : 0
# Count of null values in row  1141 : 0
# Count of null values in row  1142 : 0
# Count of null values in row  1143 : 0
# Count of null values in row  1144 : 0
# Count of null values in row  1145 : 0
# Count of null values in row  1146 : 0
# Count of null values in row  1147 : 0
# Count of null values in row  1148 : 0
# Count of null values in row  1149 : 0
# Count of null values in row  1150 : 0
# Count of null values in row  1151 : 0
# Count of null values in row  1152 : 0
# Count of null values in row  1153 : 0
# Count of null values in row  1154 : 0
# Count of null values in row  1155 : 0
# Count of null values in row  1156 : 0
# Count of null values in row  1157 : 0
# Count of null values in row  1158 : 0
# Count of null values in row  1159 : 0
# Count of null values in row  1160 : 0
# Count of null values in row  1161 : 0
# Count of null values in row  1162 : 0
# Count of null values in row  1163 : 0
# Count of null values in row  1164 : 0
# Count of null values in row  1165 : 0
# Count of null values in row  1166 : 0
# Count of null values in row  1167 : 0
# Count of null values in row  1168 : 0
# Count of null values in row  1169 : 0
# Count of null values in row  1170 : 0
# Count of null values in row  1171 : 0
# Count of null values in row  1172 : 0
# Count of null values in row  1173 : 0
# Count of null values in row  1174 : 0
# Count of null values in row  1175 : 5
# Count of null values in row  1176 : 0
# Count of null values in row  1177 : 0
# Count of null values in row  1178 : 4
# Count of null values in row  1179 : 0
# Count of null values in row  1180 : 0
# Count of null values in row  1181 : 0
# Count of null values in row  1182 : 0
# Count of null values in row  1183 : 0
# Count of null values in row  1184 : 0
# Count of null values in row  1185 : 0
# Count of null values in row  1186 : 0
# Count of null values in row  1187 : 0
# Count of null values in row  1188 : 0
# Count of null values in row  1189 : 0
# Count of null values in row  1190 : 0
# Count of null values in row  1191 : 0
# Count of null values in row  1192 : 0
# Count of null values in row  1193 : 0
# Count of null values in row  1194 : 0
# Count of null values in row  1195 : 0
# Count of null values in row  1196 : 0
# Count of null values in row  1197 : 0
# Count of null values in row  1198 : 0
# Count of null values in row  1199 : 0
# Count of null values in row  1200 : 0
# Count of null values in row  1201 : 0
# Count of null values in row  1202 : 0
# Count of null values in row  1203 : 0
# Count of null values in row  1204 : 0
# Count of null values in row  1205 : 0
# Count of null values in row  1206 : 0
# Count of null values in row  1207 : 0
# Count of null values in row  1208 : 0
# Count of null values in row  1209 : 0
# Count of null values in row  1210 : 0
# Count of null values in row  1211 : 0
# Count of null values in row  1212 : 0
# Count of null values in row  1213 : 0
# Count of null values in row  1214 : 0
# Count of null values in row  1215 : 0
# Count of null values in row  1216 : 0
# Count of null values in row  1217 : 0
# Count of null values in row  1218 : 0
# Count of null values in row  1219 : 0
# Count of null values in row  1220 : 0
# Count of null values in row  1221 : 0
# Count of null values in row  1222 : 0
# Count of null values in row  1223 : 0
# Count of null values in row  1224 : 0
# Count of null values in row  1225 : 0
# Count of null values in row  1226 : 1
# Count of null values in row  1227 : 0
# Count of null values in row  1228 : 0
# Count of null values in row  1229 : 0
# Count of null values in row  1230 : 0
# Count of null values in row  1231 : 0
# Count of null values in row  1232 : 0
# Count of null values in row  1233 : 0
# Count of null values in row  1234 : 0
# Count of null values in row  1235 : 0
# Count of null values in row  1236 : 0
# Count of null values in row  1237 : 0
# Count of null values in row  1238 : 0
# Count of null values in row  1239 : 0
# Count of null values in row  1240 : 0
# Count of null values in row  1241 : 0
# Count of null values in row  1242 : 0
# Count of null values in row  1243 : 0
# Count of null values in row  1244 : 0
# Count of null values in row  1245 : 0
# Count of null values in row  1246 : 0
# Count of null values in row  1247 : 0
# Count of null values in row  1248 : 0
# Count of null values in row  1249 : 0
# Count of null values in row  1250 : 0
# Count of null values in row  1251 : 0
# Count of null values in row  1252 : 0
# Count of null values in row  1253 : 1
# Count of null values in row  1254 : 0
# Count of null values in row  1255 : 0
# Count of null values in row  1256 : 0
# Count of null values in row  1257 : 0
# Count of null values in row  1258 : 0
# Count of null values in row  1259 : 0
# Count of null values in row  1260 : 0
# Count of null values in row  1261 : 0
# Count of null values in row  1262 : 0
# Count of null values in row  1263 : 0
# Count of null values in row  1264 : 0
# Count of null values in row  1265 : 5
# Count of null values in row  1266 : 0
# Count of null values in row  1267 : 0
# Count of null values in row  1268 : 0
# Count of null values in row  1269 : 0
# Count of null values in row  1270 : 0
# Count of null values in row  1271 : 0
# Count of null values in row  1272 : 0
# Count of null values in row  1273 : 0
# Count of null values in row  1274 : 0
# Count of null values in row  1275 : 0
# Count of null values in row  1276 : 0
# Count of null values in row  1277 : 0
# Count of null values in row  1278 : 0
# Count of null values in row  1279 : 0
# Count of null values in row  1280 : 0
# Count of null values in row  1281 : 0
# Count of null values in row  1282 : 0
# Count of null values in row  1283 : 0
# Count of null values in row  1284 : 0
# Count of null values in row  1285 : 0
# Count of null values in row  1286 : 0
# Count of null values in row  1287 : 0
# Count of null values in row  1288 : 0
# Count of null values in row  1289 : 0
# Count of null values in row  1290 : 0
# Count of null values in row  1291 : 0
# Count of null values in row  1292 : 0
# Count of null values in row  1293 : 0
# Count of null values in row  1294 : 0
# Count of null values in row  1295 : 0
# Count of null values in row  1296 : 0
# Count of null values in row  1297 : 0
# Count of null values in row  1298 : 0
# Count of null values in row  1299 : 0
# Count of null values in row  1300 : 0
# Count of null values in row  1301 : 0
# Count of null values in row  1302 : 0
# Count of null values in row  1303 : 0
# Count of null values in row  1304 : 0
# Count of null values in row  1305 : 0
# Count of null values in row  1306 : 0
# Count of null values in row  1307 : 1
# Count of null values in row  1308 : 0
# Count of null values in row  1309 : 0
# Count of null values in row  1310 : 0
# Count of null values in row  1311 : 0
# Count of null values in row  1312 : 0
# Count of null values in row  1313 : 0
# Count of null values in row  1314 : 0
# Count of null values in row  1315 : 0
# Count of null values in row  1316 : 0
# Count of null values in row  1317 : 0
# Count of null values in row  1318 : 0
# Count of null values in row  1319 : 0
# Count of null values in row  1320 : 0
# Count of null values in row  1321 : 0
# Count of null values in row  1322 : 0
# Count of null values in row  1323 : 0
# Count of null values in row  1324 : 0
# Count of null values in row  1325 : 0
# Count of null values in row  1326 : 1
# Count of null values in row  1327 : 1
# Count of null values in row  1328 : 0
# Count of null values in row  1329 : 1
# Count of null values in row  1330 : 0
# ...
# Count of null values in row  4622 : 4
# Count of null values in row  4623 : 1
# Count of null values in row  4624 : 2
# Count of null values in row  4625 : 1
# Count of null values in row  4626 : 3
# Count of null values in row  4627 : 4
# Count of null values in row  4628 : 1
# Count of null values in row  4629 : 1
# Count of null values in row  4630 : 5
# Count of null values in row  4631 : 0
# Count of null values in row  4632 : 2
# Count of null values in row  4633 : 2
# Count of null values in row  4634 : 8
# Count of null values in row  4635 : 2
# Count of null values in row  4636 : 3
# Count of null values in row  4637 : 3
# Count of null values in row  4638 : 0
# Count of null values in row  4639 : 0
# Count of null values in row  4640 : 0
# Count of null values in row  4641 : 3
# Count of null values in row  4642 : 0
# Count of null values in row  4643 : 0
# Count of null values in row  4644 : 1
# Count of null values in row  4645 : 0
# Count of null values in row  4646 : 0
# Count of null values in row  4647 : 1
# Count of null values in row  4648 : 1
# Count of null values in row  4649 : 0
# Count of null values in row  4650 : 0
# Count of null values in row  4651 : 2
# Count of null values in row  4652 : 2
# Count of null values in row  4653 : 0
# Count of null values in row  4654 : 1
# Count of null values in row  4655 : 0
# Count of null values in row  4656 : 1
# Count of null values in row  4657 : 3
# Count of null values in row  4658 : 4
# Count of null values in row  4659 : 0
# Count of null values in row  4660 : 4
# Count of null values in row  4661 : 0
# Count of null values in row  4662 : 0
# Count of null values in row  4663 : 0
# Count of null values in row  4664 : 1
# Count of null values in row  4665 : 2
# Count of null values in row  4666 : 2
# Count of null values in row  4667 : 0
# Count of null values in row  4668 : 2
# Count of null values in row  4669 : 2
# Count of null values in row  4670 : 2
# Count of null values in row  4671 : 0
# Count of null values in row  4672 : 1
# Count of null values in row  4673 : 4
# Count of null values in row  4674 : 0
# Count of null values in row  4675 : 2
# Count of null values in row  4676 : 0
# Count of null values in row  4677 : 0
# Count of null values in row  4678 : 1
# Count of null values in row  4679 : 0
# Count of null values in row  4680 : 0
# Count of null values in row  4681 : 0
# Count of null values in row  4682 : 1
# Count of null values in row  4683 : 0
# Count of null values in row  4684 : 0
# Count of null values in row  4685 : 1
# Count of null values in row  4686 : 1
# Count of null values in row  4687 : 1
# Count of null values in row  4688 : 0
# Count of null values in row  4689 : 1
# Count of null values in row  4690 : 5
# Count of null values in row  4691 : 0
# Count of null values in row  4692 : 2
# Count of null values in row  4693 : 3
# Count of null values in row  4694 : 0
# Count of null values in row  4695 : 0
# Count of null values in row  4696 : 0
# Count of null values in row  4697 : 1
# Count of null values in row  4698 : 1
# Count of null values in row  4699 : 2
# Count of null values in row  4700 : 1
# Count of null values in row  4701 : 3
# Count of null values in row  4702 : 3
# Count of null values in row  4703 : 1
# Count of null values in row  4704 : 3
# Count of null values in row  4705 : 3
# Count of null values in row  4706 : 0
# Count of null values in row  4707 : 0
# Count of null values in row  4708 : 0
# Count of null values in row  4709 : 1
# Count of null values in row  4710 : 0
# Count of null values in row  4711 : 2
# Count of null values in row  4712 : 0
# Count of null values in row  4713 : 5
# Count of null values in row  4714 : 4
# Count of null values in row  4715 : 3
# Count of null values in row  4716 : 3
# Count of null values in row  4717 : 4
# Count of null values in row  4718 : 4
# Count of null values in row  4719 : 0
# Count of null values in row  4720 : 8
# Count of null values in row  4721 : 2
# Count of null values in row  4722 : 3
# Count of null values in row  4723 : 0
# Count of null values in row  4724 : 2
# Count of null values in row  4725 : 0
# Count of null values in row  4726 : 0
# Count of null values in row  4727 : 4
# Count of null values in row  4728 : 0
# Count of null values in row  4729 : 1
# Count of null values in row  4730 : 0
# Count of null values in row  4731 : 0
# Count of null values in row  4732 : 1
# Count of null values in row  4733 : 0
# Count of null values in row  4734 : 1
# Count of null values in row  4735 : 0
# Count of null values in row  4736 : 0
# Count of null values in row  4737 : 0
# Count of null values in row  4738 : 1
# Count of null values in row  4739 : 0
# Count of null values in row  4740 : 0
# Count of null values in row  4741 : 0
# Count of null values in row  4742 : 0
# Count of null values in row  4743 : 0
# Count of null values in row  4744 : 0
# Count of null values in row  4745 : 1
# Count of null values in row  4746 : 2
# Count of null values in row  4747 : 0
# Count of null values in row  4748 : 1
# Count of null values in row  4749 : 1
# Count of null values in row  4750 : 0
# Count of null values in row  4751 : 0
# Count of null values in row  4752 : 0
# Count of null values in row  4753 : 0
# Count of null values in row  4754 : 0
# Count of null values in row  4755 : 0
# Count of null values in row  4756 : 2
# Count of null values in row  4757 : 1
# Count of null values in row  4758 : 0
# Count of null values in row  4759 : 2
# Count of null values in row  4760 : 2
# Count of null values in row  4761 : 1
# Count of null values in row  4762 : 1
# Count of null values in row  4763 : 4
# Count of null values in row  4764 : 3
# Count of null values in row  4765 : 2
# Count of null values in row  4766 : 1
# Count of null values in row  4767 : 7
# Count of null values in row  4768 : 3
# Count of null values in row  4769 : 0
# Count of null values in row  4770 : 2
# Count of null values in row  4771 : 2
# Count of null values in row  4772 : 2
# Count of null values in row  4773 : 2
# Count of null values in row  4774 : 4
# Count of null values in row  4775 : 3
# Count of null values in row  4776 : 2
# Count of null values in row  4777 : 3
# Count of null values in row  4778 : 0
# Count of null values in row  4779 : 1
# Count of null values in row  4780 : 0
# Count of null values in row  4781 : 0
# Count of null values in row  4782 : 2
# Count of null values in row  4783 : 0
# Count of null values in row  4784 : 0
# Count of null values in row  4785 : 3
# Count of null values in row  4786 : 0
# Count of null values in row  4787 : 3
# Count of null values in row  4788 : 0
# Count of null values in row  4789 : 1
# Count of null values in row  4790 : 3
# Count of null values in row  4791 : 0
# Count of null values in row  4792 : 0
# Count of null values in row  4793 : 0
# Count of null values in row  4794 : 1
# Count of null values in row  4795 : 0
# Count of null values in row  4796 : 0
# Count of null values in row  4797 : 1
# Count of null values in row  4798 : 5
# Count of null values in row  4799 : 0
# Count of null values in row  4800 : 1
# Count of null values in row  4801 : 3
# Count of null values in row  4802 : 0
# Count of null values in row  4803 : 5
# Count of null values in row  4804 : 0
# Count of null values in row  4805 : 1
# Count of null values in row  4806 : 1
# Count of null values in row  4807 : 2
# Count of null values in row  4808 : 1
# Count of null values in row  4809 : 1
# Count of null values in row  4810 : 2
# Count of null values in row  4811 : 1
# Count of null values in row  4812 : 0
# Count of null values in row  4813 : 1
# Count of null values in row  4814 : 0
# Count of null values in row  4815 : 6
# Count of null values in row  4816 : 0
# Count of null values in row  4817 : 0
# Count of null values in row  4818 : 2
# Count of null values in row  4819 : 5
# Count of null values in row  4820 : 2
# Count of null values in row  4821 : 0
# Count of null values in row  4822 : 1
# Count of null values in row  4823 : 2
# Count of null values in row  4824 : 1
# Count of null values in row  4825 : 1
# Count of null values in row  4826 : 1
# Count of null values in row  4827 : 0
# Count of null values in row  4828 : 0
# Count of null values in row  4829 : 0
# Count of null values in row  4830 : 0
# Count of null values in row  4831 : 3
# Count of null values in row  4832 : 0
# Count of null values in row  4833 : 0
# Count of null values in row  4834 : 2
# Count of null values in row  4835 : 1
# Count of null values in row  4836 : 5
# Count of null values in row  4837 : 7
# Count of null values in row  4838 : 1
# Count of null values in row  4839 : 1
# Count of null values in row  4840 : 0
# Count of null values in row  4841 : 2
# Count of null values in row  4842 : 0
# Count of null values in row  4843 : 4
# Count of null values in row  4844 : 1
# Count of null values in row  4845 : 0
# Count of null values in row  4846 : 4
# Count of null values in row  4847 : 2
# Count of null values in row  4848 : 1
# Count of null values in row  4849 : 1
# Count of null values in row  4850 : 2
# Count of null values in row  4851 : 0
# Count of null values in row  4852 : 0
# Count of null values in row  4853 : 0
# Count of null values in row  4854 : 3
# Count of null values in row  4855 : 0
# Count of null values in row  4856 : 0
# Count of null values in row  4857 : 0
# Count of null values in row  4858 : 0
# Count of null values in row  4859 : 6
# Count of null values in row  4860 : 0
# Count of null values in row  4861 : 1
# Count of null values in row  4862 : 0
# Count of null values in row  4863 : 0
# Count of null values in row  4864 : 0
# Count of null values in row  4865 : 3
# Count of null values in row  4866 : 1
# Count of null values in row  4867 : 2
# Count of null values in row  4868 : 0
# Count of null values in row  4869 : 5
# Count of null values in row  4870 : 3
# Count of null values in row  4871 : 1
# Count of null values in row  4872 : 2
# Count of null values in row  4873 : 1
# Count of null values in row  4874 : 2
# Count of null values in row  4875 : 2
# Count of null values in row  4876 : 3
# Count of null values in row  4877 : 2
# Count of null values in row  4878 : 6
# Count of null values in row  4879 : 2
# Count of null values in row  4880 : 3
# Count of null values in row  4881 : 2
# Count of null values in row  4882 : 3
# Count of null values in row  4883 : 3
# Count of null values in row  4884 : 3
# Count of null values in row  4885 : 2
# Count of null values in row  4886 : 3
# Count of null values in row  4887 : 3
# Count of null values in row  4888 : 1
# Count of null values in row  4889 : 3
# Count of null values in row  4890 : 0
# Count of null values in row  4891 : 0
# Count of null values in row  4892 : 1
# Count of null values in row  4893 : 0
# Count of null values in row  4894 : 1
# Count of null values in row  4895 : 1
# Count of null values in row  4896 : 0
# Count of null values in row  4897 : 0
# Count of null values in row  4898 : 1
# Count of null values in row  4899 : 1
# Count of null values in row  4900 : 1
# Count of null values in row  4901 : 1
# Count of null values in row  4902 : 1
# Count of null values in row  4903 : 2
# Count of null values in row  4904 : 1
# Count of null values in row  4905 : 0
# Count of null values in row  4906 : 1
# Count of null values in row  4907 : 3
# Count of null values in row  4908 : 1
# Count of null values in row  4909 : 1
# Count of null values in row  4910 : 5
# Count of null values in row  4911 : 3
# Count of null values in row  4912 : 2
# Count of null values in row  4913 : 1
# Count of null values in row  4914 : 1
# Count of null values in row  4915 : 0
# Count of null values in row  4916 : 2
# Count of null values in row  4917 : 1
# Count of null values in row  4918 : 4
# Count of null values in row  4919 : 5
# Count of null values in row  4920 : 3
# Count of null values in row  4921 : 0
# Count of null values in row  4922 : 0
# Count of null values in row  4923 : 0
# Count of null values in row  4924 : 5
# Count of null values in row  4925 : 4
# Count of null values in row  4926 : 0
# Count of null values in row  4927 : 3
# Count of null values in row  4928 : 0
# Count of null values in row  4929 : 5
# Count of null values in row  4930 : 0
# Count of null values in row  4931 : 0
# Count of null values in row  4932 : 2
# Count of null values in row  4933 : 0
# Count of null values in row  4934 : 3
# Count of null values in row  4935 : 3
# Count of null values in row  4936 : 0
# Count of null values in row  4937 : 1
# Count of null values in row  4938 : 3
# Count of null values in row  4939 : 3
# Count of null values in row  4940 : 3
# Count of null values in row  4941 : 0
# Count of null values in row  4942 : 1
# Count of null values in row  4943 : 2
# Count of null values in row  4944 : 1
# Count of null values in row  4945 : 11
# Count of null values in row  4946 : 8
# Count of null values in row  4947 : 1
# Count of null values in row  4948 : 8
# Count of null values in row  4949 : 2
# Count of null values in row  4950 : 2
# Count of null values in row  4951 : 1
# Count of null values in row  4952 : 2
# Count of null values in row  4953 : 2
# Count of null values in row  4954 : 3
# Count of null values in row  4955 : 0
# Count of null values in row  4956 : 0
# Count of null values in row  4957 : 1
# Count of null values in row  4958 : 2
# Count of null values in row  4959 : 0
# Count of null values in row  4960 : 1
# Count of null values in row  4961 : 1
# Count of null values in row  4962 : 0
# Count of null values in row  4963 : 2
# Count of null values in row  4964 : 0
# Count of null values in row  4965 : 1
# Count of null values in row  4966 : 1
# Count of null values in row  4967 : 2
# Count of null values in row  4968 : 2
# Count of null values in row  4969 : 3
# Count of null values in row  4970 : 1
# Count of null values in row  4971 : 0
# Count of null values in row  4972 : 3
# Count of null values in row  4973 : 0
# Count of null values in row  4974 : 2
# Count of null values in row  4975 : 0
# Count of null values in row  4976 : 4
# Count of null values in row  4977 : 0
# Count of null values in row  4978 : 0
# Count of null values in row  4979 : 0
# Count of null values in row  4980 : 1
# Count of null values in row  4981 : 1
# Count of null values in row  4982 : 3
# Count of null values in row  4983 : 1
# Count of null values in row  4984 : 0
# Count of null values in row  4985 : 3
# Count of null values in row  4986 : 2
# Count of null values in row  4987 : 0
# Count of null values in row  4988 : 2
# Count of null values in row  4989 : 6
# Count of null values in row  4990 : 8
# Count of null values in row  4991 : 2
# Count of null values in row  4992 : 7
# Count of null values in row  4993 : 1
# Count of null values in row  4994 : 3
# Count of null values in row  4995 : 1
# Count of null values in row  4996 : 3
# Count of null values in row  4997 : 0
# Count of null values in row  4998 : 0
# Count of null values in row  4999 : 4
# Count of null values in row  5000 : 1
# Count of null values in row  5001 : 1
# Count of null values in row  5002 : 3
# Count of null values in row  5003 : 2
# Count of null values in row  5004 : 1
# Count of null values in row  5005 : 2
# Count of null values in row  5006 : 3
# Count of null values in row  5007 : 2
# Count of null values in row  5008 : 0
# Count of null values in row  5009 : 2
# Count of null values in row  5010 : 3
# Count of null values in row  5011 : 0
# Count of null values in row  5012 : 0
# Count of null values in row  5013 : 2
# Count of null values in row  5014 : 2
# Count of null values in row  5015 : 0
# Count of null values in row  5016 : 5
# Count of null values in row  5017 : 2
# Count of null values in row  5018 : 2
# Count of null values in row  5019 : 2
# Count of null values in row  5020 : 5
# Count of null values in row  5021 : 1
# Count of null values in row  5022 : 4
# Count of null values in row  5023 : 2
# Count of null values in row  5024 : 1
# Count of null values in row  5025 : 0
# Count of null values in row  5026 : 0
# Count of null values in row  5027 : 0
# Count of null values in row  5028 : 3
# Count of null values in row  5029 : 1
# Count of null values in row  5030 : 5
# Count of null values in row  5031 : 3
# Count of null values in row  5032 : 4
# Count of null values in row  5033 : 0
# Count of null values in row  5034 : 1
# Count of null values in row  5035 : 0
# Count of null values in row  5036 : 3
# Count of null values in row  5037 : 1
# Count of null values in row  5038 : 4
# Count of null values in row  5039 : 5
# Count of null values in row  5040 : 4
# Count of null values in row  5041 : 2
# Count of null values in row  5042 : 0

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations 
movies = movies.drop(['color','director_facebook_likes','actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes',
            'actor_2_name','cast_total_facebook_likes','actor_3_name','duration','facenumber_in_poster','content_rating',
            'country','movie_imdb_link','aspect_ratio','plot_keywords'],axis=1)

# %%
movies
# Out:
#           director_name  ...  movie_facebook_likes
# 0         James Cameron  ...                 33000
# 1        Gore Verbinski  ...                     0
# 2            Sam Mendes  ...                 85000
# 3     Christopher Nolan  ...                164000
# 4           Doug Walker  ...                     0
# ...                 ...  ...                   ...
# 5038        Scott Smith  ...                    84
# 5039                NaN  ...                 32000
# 5040   Benjamin Roberds  ...                    16
# 5041        Daniel Hsia  ...                   660
# 5042           Jon Gunn  ...                   456
#
# [5043 rows x 13 columns]

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
# Write your code for dropping the rows here
Nancol = []
droprow = []
for i in movies.columns:
    if (movies[i].isnull().sum()*100/len(movies))>5:
        Nancol.append(i)
for r in range(len(movies)):
    for c in Nancol:
        if np.isnan(movies.iloc[r][c]):
            droprow.append(r)
droprow = list(set(droprow))
droprow.sort()
movies.drop(movies.index[droprow],inplace=True)
movies
# Out:
#           director_name  ...  movie_facebook_likes
# 0         James Cameron  ...                 33000
# 1        Gore Verbinski  ...                     0
# 2            Sam Mendes  ...                 85000
# 3     Christopher Nolan  ...                164000
# 5        Andrew Stanton  ...                 24000
# ...                 ...  ...                   ...
# 5033      Shane Carruth  ...                 19000
# 5034   Neill Dela Llana  ...                    74
# 5035   Robert Rodriguez  ...                     0
# 5037       Edward Burns  ...                   413
# 5042           Jon Gunn  ...                   456
#
# [3891 rows x 13 columns]

# %% [markdown]
# -  ### Subtask 2.4: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# Write your code for filling the NaN values in the 'language' column here
movies['language'].fillna('English',inplace=True)
movies
# Out:
#           director_name  ...  movie_facebook_likes
# 0         James Cameron  ...                 33000
# 1        Gore Verbinski  ...                     0
# 2            Sam Mendes  ...                 85000
# 3     Christopher Nolan  ...                164000
# 5        Andrew Stanton  ...                 24000
# ...                 ...  ...                   ...
# 5033      Shane Carruth  ...                 19000
# 5034   Neill Dela Llana  ...                    74
# 5035   Robert Rodriguez  ...                     0
# 5037       Edward Burns  ...                   413
# 5042           Jon Gunn  ...                   456
#
# [3891 rows x 13 columns]

# %% [markdown]
# -  ### Subtask 2.5: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
# Write your code for checking number of retained rows here
movies.shape[0]
# Out:
# 3891

# %%
movies.shape[0]/5043*100 #You might have noticed that we still have around 77% of the rows!
# Out:
# 77.15645449137418

# %% [markdown]
# **Checkpoint 1:** You might have noticed that we still have around `77%` of the rows!

# %% [markdown]
# ## Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
# Write your code for unit conversion here
movies['gross'] = movies['gross']/1000000
movies['budget'] = movies['gross']/1000000
movies
# Out:
#           director_name  ...  movie_facebook_likes
# 0         James Cameron  ...                 33000
# 1        Gore Verbinski  ...                     0
# 2            Sam Mendes  ...                 85000
# 3     Christopher Nolan  ...                164000
# 5        Andrew Stanton  ...                 24000
# ...                 ...  ...                   ...
# 5033      Shane Carruth  ...                 19000
# 5034   Neill Dela Llana  ...                    74
# 5035   Robert Rodriguez  ...                     0
# 5037       Edward Burns  ...                   413
# 5042           Jon Gunn  ...                   456
#
# [3891 rows x 13 columns]

# %% [markdown]
# -  ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Plot `profit` (y-axis) vs `budget` (x- axis) and observe the outliers using the appropriate chart type.
#     4. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# Write your code for creating the profit column 
movies['profit'] = abs(movies['gross']-movies['budget'])
movies
# Out:
#           director_name  ...      profit
# 0         James Cameron  ...  760.505086
# 1        Gore Verbinski  ...  309.403843
# 2            Sam Mendes  ...  200.073975
# 3     Christopher Nolan  ...  448.130194
# 5        Andrew Stanton  ...   73.058606
# ...                 ...  ...         ...
# 5033      Shane Carruth  ...    0.424760
# 5034   Neill Dela Llana  ...    0.070071
# 5035   Robert Rodriguez  ...    2.040918
# 5037       Edward Burns  ...    0.004584
# 5042           Jon Gunn  ...    0.085222
#
# [3891 rows x 14 columns]

# %%
# Write your code for sorting the dataframe here
movies.sort_values('profit',inplace=True)
movies
# Out:
#               director_name  ...      profit
# 3330    Ekachai Uekrongtham  ...    0.000162
# 4607           Frank Whaley  ...    0.000703
# 4606  Brian Trenchard-Smith  ...    0.000721
# 4915            Ricki Stern  ...    0.001111
# 4758        Alex Craig Mann  ...    0.001332
# ...                     ...  ...         ...
# 794             Joss Whedon  ...  623.278924
# 17              Joss Whedon  ...  623.278924
# 29          Colin Trevorrow  ...  652.176619
# 26            James Cameron  ...  658.671643
# 0             James Cameron  ...  760.505086
#
# [3891 rows x 14 columns]

# %%
# Write code for profit vs budget plot here
movies.plot(kind='box',x='budget',y='profit')

# %%
#here we can also draw scatter plot 
movies.plot(kind='scatter',x='budget',y='profit',color='green')

# %%
movies.plot(kind='line',x='budget',y='profit',color='blue')

# %%
 # Write your code to get the top 10 profiting movies here
top10 = movies[:-10]
top10
# Out:
#               director_name  ...      profit
# 3330    Ekachai Uekrongtham  ...    0.000162
# 4607           Frank Whaley  ...    0.000703
# 4606  Brian Trenchard-Smith  ...    0.000721
# 4915            Ricki Stern  ...    0.001111
# 4758        Alex Craig Mann  ...    0.001332
# ...                     ...  ...         ...
# 509            Roger Allers  ...  422.783354
# 13           Gore Verbinski  ...  423.032205
# 186        Francis Lawrence  ...  424.645152
# 3080       Steven Spielberg  ...  434.949024
# 582          Andrew Adamson  ...  436.470600
#
# [3881 rows x 14 columns]

# %% [markdown]
# -  ### Subtask 3.3: Drop duplicate values
#
# After you found out the top 10 profiting movies, you might have noticed a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat `Subtask 3.2`. Note that the same `movie_title` can be there in different languages.

# %%
# Write your code for dropping duplicate values here
movies.drop_duplicates(inplace = True)

# %%
# Write code for repeating subtask 2 here

movies['profit'] = abs(movies['gross']-movies['budget'])

# Write your code for sorting the dataframe here
movies.sort_values('profit',inplace=True,ascending=False)

# Write code for profit vs budget plot here
movies.plot(x='budget',y='profit')

# Write your code to get the top 10 profiting movies here
top10 = movies[:10]
top10
# Out:
#           director_name  ...      profit
# 0         James Cameron  ...  760.505086
# 26        James Cameron  ...  658.671643
# 29      Colin Trevorrow  ...  652.176619
# 794         Joss Whedon  ...  623.278924
# 66    Christopher Nolan  ...  533.315528
# 240        George Lucas  ...  474.544202
# 3024       George Lucas  ...  460.935204
# 8           Joss Whedon  ...  458.991140
# 3     Christopher Nolan  ...  448.130194
# 582      Andrew Adamson  ...  436.470600
#
# [10 rows x 14 columns]

# %% [markdown]
# **Checkpoint 2:** You might spot two movies directed by `James Cameron` in the list.

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'

# %%
Top_Foreign_Lang_Film = # Write your code to extract top foreign language films from 'IMDb_Top_250' here

# %% [markdown]
# **Checkpoint 3:** Can you spot `Veer-Zaara` in the dataframe?

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Group the dataframe using the `director_name` column.
#     2. Find out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.  Incase of a tie in IMDb score between two directors, sort them alphabetically.

# %%
# Write your code for extracting the top 10 directors here
movies.sort_values('imdb_score',inplace=True,ascending=False)
IMDB_Top_250 = movies[movies['num_voted_users']>25000].iloc[0:250]
IMDB_Top_250['Rank']=np.array([i for i in range(1,251,1)])
IMDB_Top_250.set_index('Rank',inplace=True)
IMDB_Top_250
# Out:
#              director_name  ...      profit
# Rank                        ...
# 1           Frank Darabont  ...   28.341441
# 2     Francis Ford Coppola  ...  134.821817
# 3        Christopher Nolan  ...  533.315528
# 4     Francis Ford Coppola  ...   57.299943
# 5            Peter Jackson  ...  377.018875
# ...                    ...  ...         ...
# 246            Paul Haggis  ...   54.557293
# 247            Yimou Zhang  ...    0.084961
# 248          John Lasseter  ...  245.823151
# 249           Michael Mann  ...   28.965168
# 250        Nick Cassavetes  ...    0.064286
#
# [250 rows x 14 columns]

# %% [markdown]
# **Checkpoint 4:** No surprises that `Damien Chazelle` (director of Whiplash and La La Land) is in this list.

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extract the first two genres from the `genres` column and store them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
# Write your code for extracting the first two genres of each movie here
Top_Foreign_Lang_Film = IMDB_Top_250[IMDB_Top_250['language']!='English'].movie_title

Top_Foreign_Lang_Film
# Out:
# Rank
# 8          The Good, the Bad and the Ugly
# 14                          Seven Samurai
# 19                            City of God
# 22                          Spirited Away
# 38                     Children of Heaven
# 45                    The Lives of Others
# 50                               Das Boot
# 51                                 Oldboy
# 57                      Princess Mononoke
# 58               Baahubali: The Beginning
# 59                                 Amélie
# 60                           A Separation
# 79                               The Hunt
# 81                               Downfall
# 84                             Metropolis
# 92                        Pan's Labyrinth
# 98                   Howl's Moving Castle
# 106                             Incendies
# 107              The Secret in Their Eyes
# 111                                 Akira
# 121    Tae Guk Gi: The Brotherhood of War
# 134                         Amores Perros
# 139                           Elite Squad
# 144                        The Sea Inside
# 150                       The Celebration
# 160                       Central Station
# 168                       My Name Is Khan
# 172                  A Fistful of Dollars
# 179                            Persepolis
# 183                     Waltz with Bashir
# 210                            Veer-Zaara
# 214          4 Months, 3 Weeks and 2 Days
# 215                           Nine Queens
# 217        Crouching Tiger, Hidden Dragon
# 218                            The Chorus
# 226                 Letters from Iwo Jima
# 233                                 Amour
# 247                                  Hero
# Name: movie_title, dtype: object

# %%
 # Write your code for grouping the dataframe here
movies_by_segment= movies.groupby('director_name').imdb_score.mean().sort_values(ascending=False)[:10].sort_index()
top10director = movies_by_segment.index
top10director
# Out:
# Index(['Alfred Hitchcock', 'Asghar Farhadi', 'Charles Chaplin',
#        'Christopher Nolan', 'Damien Chazelle', 'Majid Majidi', 'Ron Fricke',
#        'S.S. Rajamouli', 'Sergio Leone', 'Tony Kaye'],
#       dtype='object', name='director_name')

# %%
#PopGenre = # Write your code for getting the 5 most popular combo of genres here
genre_1 = []
genre_2 = []
for i in movies['genres']:
    x = [j for j in i.split('|')]
    if len(x)==1:
        genre_1.append(x[0])
        genre_2.append(x[0])
    else:
        genre_1.append(x[0])
        genre_2.append(x[1])

# %%
# Write your code for grouping the dataframe here
movies['genre_1'] = genre_1
movies['genre_2'] = genre_2
movies_by_segment = movies.groupby(['genre_1','genre_2'])

# %%
# Write your code for getting the 5 most popular combo of genres here
PopGenre = movies_by_segment.gross.mean().sort_values(ascending=False).index
PopGenre
# Out:
# MultiIndex([(     'Family',      'Sci-Fi'),
#             (  'Adventure',      'Sci-Fi'),
#             (  'Adventure',      'Family'),
#             (  'Adventure',   'Animation'),
#             (     'Action',   'Adventure'),
#             (    'Fantasy',     'Mystery'),
#             (  'Animation',      'Comedy'),
#             (     'Action',   'Animation'),
#             (    'Musical',     'Romance'),
#             (  'Adventure',     'Fantasy'),
#             ...
#             (    'Fantasy',    'Thriller'),
#             ('Documentary',         'War'),
#             (  'Biography', 'Documentary'),
#             (     'Comedy',     'History'),
#             ('Documentary',       'Sport'),
#             (     'Horror',     'Musical'),
#             (    'Romance',     'Romance'),
#             (   'Thriller',    'Thriller'),
#             (     'Sci-Fi',      'Sci-Fi'),
#             (  'Adventure',         'War')],
#            names=['genre_1', 'genre_2'], length=103)

# %% [markdown]
# **Checkpoint 5:** Well, as it turns out. `Family + Sci-Fi` is the most popular combo of genres out there!

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_users_for_review` and identify the actors which have the highest mean.
#     5. Observe the change in number of voted users over decades using a bar chart. Create a column called `decade` which represents the decade to which every movie belongs to. For example, the  `title_year`  year 1923, 1925 should be stored as 1920s. Sort the dataframe based on the column `decade`, group it by `decade` and find the sum of users voted in each decade. Store this in a new data frame called `df_by_decade`.

# %%
# Write your code for creating three new dataframes here
# Include all movies in which Meryl_Streep is the lead
Meryl_Streep = movies[movies['actor_1_name']=='Meryl Streep']

# %%
Leo_Caprio = movies[movies['actor_1_name']=='Leonardo DiCaprio'] # Include all movies in which Leo_Caprio is the lead

# %%
Brad_Pitt =movies[movies['actor_1_name']=='Brad Pitt'] # Include all movies in which Brad_Pitt is the lead

# %%
# Write your code for combining the three dataframes here
combine=Meryl_Streep.append(Leo_Caprio).append(Brad_Pitt)

# %%
# Write your code for grouping the combined dataframe here
table = combine.groupby('actor_1_name')

# %%
# Write the code for finding the mean of critic reviews and audience reviews here
table.num_critic_for_reviews.mean().sort_values(ascending=False)
# Out:
# actor_1_name
# Leonardo DiCaprio    330.190476
# Brad Pitt            245.000000
# Meryl Streep         181.454545
# Name: num_critic_for_reviews, dtype: float64

# %% [markdown]
# **Checkpoint 6:** `Leonardo` has aced both the lists!

# %%
# Write the code for calculating decade here
combine['decade'] = (combine['title_year']//10)*10
combine['decade'].astype('int64')
combine
# Out:
#               director_name  num_critic_for_reviews  ...    genre_2  decade
# 1925         Stephen Daldry                   174.0  ...    Romance  2000.0
# 1575         Sydney Pollack                    66.0  ...      Drama  1980.0
# 1674          Carl Franklin                    64.0  ...      Drama  1990.0
# 1204            Nora Ephron                   252.0  ...      Drama  2000.0
# 3135          Robert Altman                   211.0  ...      Drama  2000.0
# 1408          David Frankel                   208.0  ...      Drama  2000.0
# 410            Nancy Meyers                   187.0  ...      Drama  2000.0
# 2781         Phyllida Lloyd                   331.0  ...      Drama  2010.0
# 1106          Curtis Hanson                    42.0  ...  Adventure  1990.0
# 1618          David Frankel                   234.0  ...      Drama  2010.0
# 1483         Robert Redford                   227.0  ...   Thriller  2000.0
# 97        Christopher Nolan                   642.0  ...  Adventure  2010.0
# 361         Martin Scorsese                   352.0  ...      Drama  2000.0
# 296       Quentin Tarantino                   765.0  ...    Western  2010.0
# 308         Martin Scorsese                   606.0  ...     Comedy  2010.0
# 179   Alejandro G. Iñárritu                   556.0  ...      Drama  2010.0
# 452         Martin Scorsese                   490.0  ...   Thriller  2010.0
# 911        Steven Spielberg                   194.0  ...      Crime  2000.0
# 307            Edward Zwick                   166.0  ...      Drama  2000.0
# 26            James Cameron                   315.0  ...    Romance  1990.0
# 326         Martin Scorsese                   233.0  ...      Drama  2000.0
# 257         Martin Scorsese                   267.0  ...      Drama  2000.0
# 1114             Sam Mendes                   323.0  ...    Romance  2000.0
# 50             Baz Luhrmann                   490.0  ...    Romance  2010.0
# 3476           Baz Luhrmann                   490.0  ...    Romance  2010.0
# 641            Ridley Scott                   238.0  ...      Drama  2000.0
# 2757           Baz Luhrmann                   106.0  ...    Romance  1990.0
# 2067             Jerry Zaks                    45.0  ...      Drama  1990.0
# 1453         Clint Eastwood                   392.0  ...      Crime  2010.0
# 990             Danny Boyle                   118.0  ...      Drama  2000.0
# 1560              Sam Raimi                    63.0  ...   Thriller  1990.0
# 1422        Randall Wallace                    83.0  ...  Adventure  1990.0
# 683           David Fincher                   315.0  ...      Drama  1990.0
# 2898             Tony Scott                   122.0  ...      Crime  1990.0
# 101           David Fincher                   362.0  ...    Fantasy  2000.0
# 400       Steven Soderbergh                   186.0  ...   Thriller  2000.0
# 940             Neil Jordan                   120.0  ...    Fantasy  1990.0
# 470              David Ayer                   406.0  ...      Drama  2010.0
# 2204  Alejandro G. Iñárritu                   285.0  ...      Drama  2000.0
# 1722         Andrew Dominik                   273.0  ...      Crime  2000.0
# 147       Wolfgang Petersen                   220.0  ...  Adventure  2000.0
# 382              Tony Scott                   142.0  ...      Crime  2000.0
# 611     Jean-Jacques Annaud                    76.0  ...  Biography  1990.0
# 792         Patrick Gilmore                    98.0  ...  Animation  2000.0
# 1490        Terrence Malick                   584.0  ...    Fantasy  2010.0
# 255              Doug Liman                   233.0  ...     Comedy  2000.0
# 254       Steven Soderbergh                   198.0  ...   Thriller  2000.0
# 2682         Andrew Dominik                   414.0  ...   Thriller  2010.0
# 2333    Angelina Jolie Pitt                   131.0  ...    Romance  2010.0
#
# [49 rows x 17 columns]

# %%
# Write your code for creating the data frame df_by_decade here 
df_by_decade = combine.groupby('decade').num_voted_users.sum().sort_index()
df_by_decade
# Out:
# decade
# 1980.0      52339
# 1990.0    3064305
# 2000.0    5894033
# 2010.0    5900385
# Name: num_voted_users, dtype: int64

# %%
# Write your code for plotting number of voted users vs decade
df_by_decade.plot(kind='bar',ylabel='Voters',xlabel='Decade',color='blue')
